# %% [markdown]
# # **1. The Metric Trap**
# - __Act 3__: The Verdict (Business Value Analysis).
# - **Goal:** Reveal that while LightGBM won on "Math" (RMSE), N-BEATSx won on "Business" (WRMSSE), and conclude with the architectural decision.
# - Explain RMSE vs. WRMSSE.
# - *Physics Analogy:* RMSE is "Energy minimization" (dominated by large masses/high-volume items). WRMSSE is "Field stability" (weighted by economic importance across the whole system).

# %% [markdown]
# # **2. Computing WRMSSE**
# - Import your metric logic: `from src.metrics import wrmsse`.
# - Compute WRMSSE for Global LightGBM.
# - Compute WRMSSE for Global N-BEATSx.

# %% [markdown]
# # **3. The Scorecard (The Climax)**
# - Display the final table:
#     - LightGBM WRMSSE: **1.94** (Failed).
#     - N-BEATSx WRMSSE: **0.93** (Success).
#     - **Analysis:** Explain *why*. (LightGBM likely predicted flat zeros or noise for the difficult "long tail" items, ruining its scaled score. N-BEATSx used global signals to stabilize those predictions).

# %% [markdown]
# # **4. Final Recommendation**
# - **Decision:** "Deploy Global N-BEATSx."
# - **Justification:** "It provides the only solution that beats the naive benchmark across the full portfolio."

# %% [markdown]
# # **5. Future Architecture (The Cloud Diagram)**
# - Briefly describe the production plan: "Dockerized N-BEATSx -> AWS Lambda."
# - (Optional) Load the saved N-BEATSx model and run one sample inference to prove it works "in production mode."
